# %%
# ============================================================================
# ASL ALPHABET FEATURE EXTRACTION - PHASE 1 (SIMPLIFIED & FIXED)
# ============================================================================

# --- STEP 1: INSTALL DEPENDENCIES ---
print("📦 Installing required packages...")
print("=" * 60)
# !pip install -q mediapipe opencv-python-headless
print("✅ All packages installed successfully!\n")

# --- STEP 2: IMPORT LIBRARIES ---
print("📚 Importing libraries...")
print("=" * 60)
import os
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
import pickle
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings('ignore')
print("✅ All libraries imported successfully!\n")

# --- STEP 3: CONFIGURATION ---
print("⚙️ Setting up configuration...")
print("=" * 60)
DATASET_PATH = "/kaggle/input/asl-alphabet/asl_alphabet_train/asl_alphabet_train"
print(f"✅ Dataset path: {DATASET_PATH}\n")

# --- STEP 4: INITIALIZE MEDIAPIPE ---
print("🤖 Initializing MediaPipe Hand Detection...")
print("=" * 60)
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(
    static_image_mode=True,
    max_num_hands=1,
    min_detection_confidence=0.5
)
print("✅ MediaPipe initialized successfully!\n")

# --- STEP 5: FEATURE EXTRACTION FUNCTION ---
def extract_hand_landmarks(image_path):
    try:
        img = cv2.imread(image_path)
        if img is None: 
            return None
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = hands.process(img_rgb)
        
        if results.multi_hand_landmarks:
            hand_landmarks = results.multi_hand_landmarks[0]
            wrist = hand_landmarks.landmark[0]
            flat_landmarks = []
            for landmark in hand_landmarks.landmark:
                flat_landmarks.append(landmark.x - wrist.x)
                flat_landmarks.append(landmark.y - wrist.y)
                flat_landmarks.append(landmark.z - wrist.z)
            return flat_landmarks
        return None
    except:
        return None

# --- STEP 6: EXTRACT LANDMARKS ---
print("🚀 Starting feature extraction...")
print("=" * 60)

landmark_data = []
stats = {'total_processed': 0, 'successful': 0, 'failed': 0}

class_folders = sorted([f for f in os.listdir(DATASET_PATH) 
                        if os.path.isdir(os.path.join(DATASET_PATH, f))])

for label_folder in class_folders:
    folder_path = os.path.join(DATASET_PATH, label_folder)
    print(f"\n📂 Processing class: {label_folder}")
    
    try:
        image_files = [f for f in os.listdir(folder_path) 
                      if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
        if not image_files:
            print(f"  ⚠️ No images in {label_folder}")
            continue
    except Exception as e:
        print(f"  ❌ Error: {e}")
        continue
    
    for image_name in tqdm(image_files, desc=f"  {label_folder}", leave=False):
        image_path = os.path.join(folder_path, image_name)
        stats['total_processed'] += 1
        
        landmarks = extract_hand_landmarks(image_path)
        
        if landmarks is not None:
            landmark_data.append([label_folder] + landmarks)
            stats['successful'] += 1
        else:
            stats['failed'] += 1
    
    print(f"  ✅ Processed {len(image_files)} images")

# Close MediaPipe
try:
    hands.close()
except:
    pass

print("\n" + "=" * 60)
print("✅ EXTRACTION COMPLETE!")
print(f"📊 Total: {stats['total_processed']}")
print(f"✅ Success: {stats['successful']}")
print(f"❌ Failed: {stats['failed']}")
print(f"📈 Rate: {(stats['successful']/stats['total_processed']*100):.2f}%\n")

# --- STEP 7: CREATE DATAFRAME ---
print("📊 Creating dataset...")
print("=" * 60)

column_names = ['label']
for i in range(21):
    column_names.extend([f'x{i}', f'y{i}', f'z{i}'])

df = pd.DataFrame(landmark_data, columns=column_names)

print(f"✅ Shape: {df.shape}")
print(f"🏷️ Classes: {df['label'].nunique()}")

# --- STEP 8: VALIDATION ---
print("\n🔍 Class distribution:")
print("=" * 60)
class_counts = df['label'].value_counts().sort_index()
print(class_counts)

# --- STEP 9: SAVE ---
print("\n💾 Saving...")
print("=" * 60)
df.to_pickle("asl_landmarks.pkl")
print("✅ Saved: asl_landmarks.pkl")

print("\n🎉 PHASE 1 COMPLETE!\n")
# Out:
# 📦 Installing required packages...
# ============================================================
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 37.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 16.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.25.8 which is incompatible.
# google-cloud-bigtable 2.32.0 requires google-api-core[grpc]<3.0.0,>=2.17.0, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.1 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# dataproc-spark-connect 0.8.3 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# ✅ All packages installed successfully!
#
# 📚 Importing libraries...
# ============================================================
# 2025-11-04 18:43:07.174499: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762281787.413589      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762281787.485509      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ✅ All libraries imported successfully!
#
# ⚙️ Setting up configuration...
# ============================================================
# ✅ Dataset path: /kaggle/input/asl-alphabet/asl_alphabet_train/asl_alphabet_train
#
# 🤖 Initializing MediaPipe Hand Detection...
# ============================================================
# ✅ MediaPipe initialized successfully!
#
# 🚀 Starting feature extraction...
# ============================================================
#
# 📂 Processing class: A
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1762281801.105890      74 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
#   A:   0%|          | 0/3000 [00:00<?, ?it/s]
# W0000 00:00:1762281801.142924      74 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762281801.161137      75 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
#   ✅ Processed 3000 images
#
# 📂 Processing class: B
#   B:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: C
#   C:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: D
#   D:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: E
#   E:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: F
#   F:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: G
#   G:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: H
#   H:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: I
#   I:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: J
#   J:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: K
#   K:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: L
#   L:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: M
#   M:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: N
#   N:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: O
#   O:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: P
#   P:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: Q
#   Q:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: R
#   R:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: S
#   S:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: T
#   T:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: U
#   U:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: V
#   V:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: W
#   W:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: X
#   X:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: Y
#   Y:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: Z
#   Z:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: del
#   del:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: nothing
#   nothing:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# 📂 Processing class: space
#   space:   0%|          | 0/3000 [00:00<?, ?it/s]
#   ✅ Processed 3000 images
#
# ============================================================
# ✅ EXTRACTION COMPLETE!
# 📊 Total: 87000
# ✅ Success: 63676
# ❌ Failed: 23324
# 📈 Rate: 73.19%
#
# 📊 Creating dataset...
# ============================================================
# ✅ Shape: (63676, 64)
# 🏷️ Classes: 29
#
# 🔍 Class distribution:
# ============================================================
# label
# A          2187
# B          2207
# C          1988
# D          2463
# E          2308
# F          2876
# G          2440
# H          2393
# I          2384
# J          2578
# K          2700
# L          2527
# M          1565
# N          1276
# O          2265
# P          2042
# Q          2093
# R          2541
# S          2551
# T          2349
# U          2516
# V          2548
# W          2456
# X          2158
# Y          2585
# Z          2351
# del        1701
# nothing       3
# space      1625
# Name: count, dtype: int64
#
# 💾 Saving...
# ============================================================
# ✅ Saved: asl_landmarks.pkl
#
# 🎉 PHASE 1 COMPLETE!

# %%
# ============================================================================
# ASL ALPHABET MODEL TRAINING - PHASE 2 (FIXED)
# ============================================================================

# --- STEP 1: INSTALL DEPENDENCIES (FIXED!) ---
print("📦 Installing required packages...")
print("=" * 60)

# Only install what's missing - let Kaggle handle scikit-learn!
# !pip install -q matplotlib seaborn

print("✅ All packages installed successfully!\n")

# --- STEP 2: IMPORT LIBRARIES ---
print("📚 Importing libraries...")
print("=" * 60)

import os
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Scikit-learn (use Kaggle's version)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(f"✅ TensorFlow version: {tf.__version__}")
print(f"✅ GPU Available: {tf.config.list_physical_devices('GPU')}")
print("✅ All libraries imported successfully!\n")

# --- STEP 3: LOAD DATA ---
print("📂 Loading processed data...")
print("=" * 60)

df = pd.read_pickle("/kaggle/input/signlanguage/asl_landmarks.pkl")
print(f"✅ Loaded!")
print(f"📏 Shape: {df.shape}")
print(f"🏷️ Classes: {df['label'].nunique()}\n")

# --- STEP 4: PREPARE DATA ---
print("🔧 Preparing data...")
print("=" * 60)

X = df.drop('label', axis=1).values
y = df['label'].values

print(f"✅ Features: {X.shape}")
print(f"✅ Labels: {y.shape}")

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)
print(f"✅ Classes: {num_classes}\n")

# --- STEP 5: TRAIN-TEST SPLIT ---
print("✂️ Splitting data...")
print("=" * 60)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

print(f"✅ Train: {X_train.shape[0]}")
print(f"✅ Test: {X_test.shape[0]}\n")

# --- STEP 6: SCALE FEATURES ---
print("📊 Scaling features...")
print("=" * 60)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("✅ Features scaled!\n")

# --- STEP 7: BUILD MODEL ---
print("🏗️ Building model...")
print("=" * 60)

keras.backend.clear_session()

model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("✅ Model built!")
model.summary()

# --- STEP 8: CALLBACKS ---
print("\n⚙️ Setting up callbacks...")
print("=" * 60)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_asl_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

callbacks = [early_stopping, reduce_lr, checkpoint]
print("✅ Callbacks ready!\n")

# --- STEP 9: TRAIN ---
print("🚀 Training...")
print("=" * 60)

history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_test_scaled, y_test),
    epochs=100,
    batch_size=128,
    callbacks=callbacks,
    verbose=1
)

print("\n✅ Training complete!\n")

# --- STEP 10: EVALUATE ---
print("📊 Evaluating...")
print("=" * 60)

model.load_weights('best_asl_model.h5')

y_pred = model.predict(X_test_scaled, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)

test_accuracy = accuracy_score(y_test, y_pred_classes)
train_loss, train_accuracy = model.evaluate(X_train_scaled, y_train, verbose=0)
test_loss, _ = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f"📈 Results:")
print(f"  Train Accuracy: {train_accuracy*100:.2f}%")
print(f"  Test Accuracy: {test_accuracy*100:.2f}%")
print(f"  Train Loss: {train_loss:.4f}")
print(f"  Test Loss: {test_loss:.4f}\n")

# --- STEP 11: CLASSIFICATION REPORT ---
print("📋 Classification Report:")
print("=" * 60)
report = classification_report(
    y_test, y_pred_classes,
    target_names=label_encoder.classes_,
    digits=3
)
print(report)

# --- STEP 12: CONFUSION MATRIX ---
print("\n📊 Confusion Matrix...")
print("=" * 60)

cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(20, 16))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=label_encoder.classes_,
    yticklabels=label_encoder.classes_
)
plt.title('Confusion Matrix', fontsize=16)
plt.xlabel('Predicted', fontsize=12)
plt.ylabel('True', fontsize=12)
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150)
plt.show()

# --- STEP 13: TRAINING CURVES ---
print("\n📈 Training curves...")
print("=" * 60)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].plot(history.history['accuracy'], label='Train')
axes[0].plot(history.history['val_accuracy'], label='Val')
axes[0].set_title('Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True)

axes[1].plot(history.history['loss'], label='Train')
axes[1].plot(history.history['val_loss'], label='Val')
axes[1].set_title('Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.savefig('training_history.png', dpi=150)
plt.show()

# --- STEP 14: SAVE EVERYTHING ---
print("\n💾 Saving files...")
print("=" * 60)

model.save('asl_model.h5')
print("✅ asl_model.h5")

with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(label_encoder, f)
print("✅ label_encoder.pkl")

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("✅ scaler.pkl")

print("\n" + "=" * 60)
print("🎉 PHASE 2 COMPLETE!")
print("=" * 60)
print("\n📥 Download these 3 files:")
print("  • asl_model.h5")
print("  • label_encoder.pkl")
print("  • scaler.pkl")
print("\n🚀 Next: Build Streamlit app!")
# Out:
# 📦 Installing required packages...
# ============================================================
# ✅ All packages installed successfully!
#
# 📚 Importing libraries...
# ============================================================
# ✅ TensorFlow version: 2.18.0
# ✅ GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ All libraries imported successfully!
#
# 📂 Loading processed data...
# ============================================================
# ✅ Loaded!
# 📏 Shape: (63676, 64)
# 🏷️ Classes: 29
#
# 🔧 Preparing data...
# ============================================================
# ✅ Features: (63676, 63)
# ✅ Labels: (63676,)
# ✅ Classes: 29
#
# ✂️ Splitting data...
# ============================================================
# ✅ Train: 50940
# ✅ Test: 12736
#
# 📊 Scaling features...
# ============================================================
# ✅ Features scaled!
#
# 🏗️ Building model...
# ============================================================
# I0000 00:00:1762284377.548040      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# ✅ Model built!
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 29)             │         1,885 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,213 (239.11 KB)
#  Trainable params: 60,317 (235.61 KB)
#  Non-trainable params: 896 (3.50 KB)
# ⚙️ Setting up callbacks...
# ============================================================
# ✅ Callbacks ready!
#
# 🚀 Training...
# ============================================================
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762284381.308260      95 service.cc:148] XLA service 0x4764ad00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762284381.308907      95 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1762284381.719102      95 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  64/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3204 - loss: 2.6339
# I0000 00:00:1762284384.210784      95 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6891 - loss: 1.2217
# Epoch 1: val_accuracy improved from -inf to 0.96836, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.6895 - loss: 1.2201 - val_accuracy: 0.9684 - val_loss: 0.1210 - learning_rate: 0.0010
# Epoch 2/100
# 386/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9595 - loss: 0.1584
# Epoch 2: val_accuracy improved from 0.96836 to 0.97731, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9596 - loss: 0.1580 - val_accuracy: 0.9773 - val_loss: 0.0805 - learning_rate: 0.0010
# Epoch 3/100
# 396/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1201
# Epoch 3: val_accuracy improved from 0.97731 to 0.98249, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9670 - loss: 0.1201 - val_accuracy: 0.9825 - val_loss: 0.0655 - learning_rate: 0.0010
# Epoch 4/100
# 391/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9726 - loss: 0.1000
# Epoch 4: val_accuracy improved from 0.98249 to 0.98430, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9726 - loss: 0.0999 - val_accuracy: 0.9843 - val_loss: 0.0585 - learning_rate: 0.0010
# Epoch 5/100
# 385/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9751 - loss: 0.0885
# Epoch 5: val_accuracy improved from 0.98430 to 0.98579, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9751 - loss: 0.0886 - val_accuracy: 0.9858 - val_loss: 0.0550 - learning_rate: 0.0010
# Epoch 6/100
# 391/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9768 - loss: 0.0810
# Epoch 6: val_accuracy did not improve from 0.98579
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9769 - loss: 0.0810 - val_accuracy: 0.9850 - val_loss: 0.0535 - learning_rate: 0.0010
# Epoch 7/100
# 383/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.0736
# Epoch 7: val_accuracy improved from 0.98579 to 0.98807, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9775 - loss: 0.0736 - val_accuracy: 0.9881 - val_loss: 0.0450 - learning_rate: 0.0010
# Epoch 8/100
# 390/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9808 - loss: 0.0695
# Epoch 8: val_accuracy did not improve from 0.98807
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9807 - loss: 0.0695 - val_accuracy: 0.9881 - val_loss: 0.0449 - learning_rate: 0.0010
# Epoch 9/100
# 390/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9817 - loss: 0.0628
# Epoch 9: val_accuracy improved from 0.98807 to 0.98885, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9817 - loss: 0.0629 - val_accuracy: 0.9889 - val_loss: 0.0413 - learning_rate: 0.0010
# Epoch 10/100
# 388/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9819 - loss: 0.0627
# Epoch 10: val_accuracy did not improve from 0.98885
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9818 - loss: 0.0628 - val_accuracy: 0.9882 - val_loss: 0.0419 - learning_rate: 0.0010
# Epoch 11/100
# 392/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9817 - loss: 0.0611
# Epoch 11: val_accuracy improved from 0.98885 to 0.98948, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9817 - loss: 0.0611 - val_accuracy: 0.9895 - val_loss: 0.0381 - learning_rate: 0.0010
# Epoch 12/100
# 386/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9829 - loss: 0.0576
# Epoch 12: val_accuracy did not improve from 0.98948
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9829 - loss: 0.0577 - val_accuracy: 0.9888 - val_loss: 0.0410 - learning_rate: 0.0010
# Epoch 13/100
# 389/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9828 - loss: 0.0613
# Epoch 13: val_accuracy did not improve from 0.98948
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9828 - loss: 0.0612 - val_accuracy: 0.9893 - val_loss: 0.0389 - learning_rate: 0.0010
# Epoch 14/100
# 395/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9831 - loss: 0.0560
# Epoch 14: val_accuracy improved from 0.98948 to 0.99089, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9831 - loss: 0.0559 - val_accuracy: 0.9909 - val_loss: 0.0362 - learning_rate: 0.0010
# Epoch 15/100
# 395/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0506
# Epoch 15: val_accuracy did not improve from 0.99089
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9853 - loss: 0.0506 - val_accuracy: 0.9901 - val_loss: 0.0353 - learning_rate: 0.0010
# Epoch 16/100
# 377/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9858 - loss: 0.0461
# Epoch 16: val_accuracy did not improve from 0.99089
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9858 - loss: 0.0463 - val_accuracy: 0.9902 - val_loss: 0.0361 - learning_rate: 0.0010
# Epoch 17/100
# 378/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9841 - loss: 0.0530
# Epoch 17: val_accuracy did not improve from 0.99089
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9842 - loss: 0.0529 - val_accuracy: 0.9903 - val_loss: 0.0348 - learning_rate: 0.0010
# Epoch 18/100
# 395/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0454
# Epoch 18: val_accuracy did not improve from 0.99089
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9867 - loss: 0.0454 - val_accuracy: 0.9899 - val_loss: 0.0350 - learning_rate: 0.0010
# Epoch 19/100
# 396/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0464
# Epoch 19: val_accuracy improved from 0.99089 to 0.99128, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9861 - loss: 0.0464 - val_accuracy: 0.9913 - val_loss: 0.0365 - learning_rate: 0.0010
# Epoch 20/100
# 394/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9856 - loss: 0.0491
# Epoch 20: val_accuracy did not improve from 0.99128
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9856 - loss: 0.0491 - val_accuracy: 0.9912 - val_loss: 0.0336 - learning_rate: 0.0010
# Epoch 21/100
# 387/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9865 - loss: 0.0446
# Epoch 21: val_accuracy did not improve from 0.99128
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9865 - loss: 0.0447 - val_accuracy: 0.9907 - val_loss: 0.0345 - learning_rate: 0.0010
# Epoch 22/100
# 384/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0492
# Epoch 22: val_accuracy improved from 0.99128 to 0.99223, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9853 - loss: 0.0492 - val_accuracy: 0.9922 - val_loss: 0.0295 - learning_rate: 0.0010
# Epoch 23/100
# 391/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0415
# Epoch 23: val_accuracy did not improve from 0.99223
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0416 - val_accuracy: 0.9907 - val_loss: 0.0345 - learning_rate: 0.0010
# Epoch 24/100
# 387/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9871 - loss: 0.0429
# Epoch 24: val_accuracy did not improve from 0.99223
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9871 - loss: 0.0429 - val_accuracy: 0.9910 - val_loss: 0.0330 - learning_rate: 0.0010
# Epoch 25/100
# 390/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0413
# Epoch 25: val_accuracy improved from 0.99223 to 0.99231, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9873 - loss: 0.0413 - val_accuracy: 0.9923 - val_loss: 0.0312 - learning_rate: 0.0010
# Epoch 26/100
# 386/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9874 - loss: 0.0433
# Epoch 26: val_accuracy did not improve from 0.99231
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9874 - loss: 0.0432 - val_accuracy: 0.9914 - val_loss: 0.0313 - learning_rate: 0.0010
# Epoch 27/100
# 388/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9888 - loss: 0.0381
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 27: val_accuracy did not improve from 0.99231
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9888 - loss: 0.0382 - val_accuracy: 0.9920 - val_loss: 0.0303 - learning_rate: 0.0010
# Epoch 28/100
# 392/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0361
# Epoch 28: val_accuracy improved from 0.99231 to 0.99333, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9893 - loss: 0.0361 - val_accuracy: 0.9933 - val_loss: 0.0277 - learning_rate: 5.0000e-04
# Epoch 29/100
# 383/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.0334
# Epoch 29: val_accuracy did not improve from 0.99333
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9894 - loss: 0.0333 - val_accuracy: 0.9928 - val_loss: 0.0268 - learning_rate: 5.0000e-04
# Epoch 30/100
# 391/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0275
# Epoch 30: val_accuracy improved from 0.99333 to 0.99340, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9914 - loss: 0.0276 - val_accuracy: 0.9934 - val_loss: 0.0281 - learning_rate: 5.0000e-04
# Epoch 31/100
# 383/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0292
# Epoch 31: val_accuracy improved from 0.99340 to 0.99419, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9912 - loss: 0.0292 - val_accuracy: 0.9942 - val_loss: 0.0249 - learning_rate: 5.0000e-04
# Epoch 32/100
# 384/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.0312
# Epoch 32: val_accuracy did not improve from 0.99419
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0312 - val_accuracy: 0.9930 - val_loss: 0.0265 - learning_rate: 5.0000e-04
# Epoch 33/100
# 392/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0302
# Epoch 33: val_accuracy did not improve from 0.99419
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0301 - val_accuracy: 0.9942 - val_loss: 0.0251 - learning_rate: 5.0000e-04
# Epoch 34/100
# 386/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0293
# Epoch 34: val_accuracy did not improve from 0.99419
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9913 - loss: 0.0293 - val_accuracy: 0.9933 - val_loss: 0.0256 - learning_rate: 5.0000e-04
# Epoch 35/100
# 384/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0299
# Epoch 35: val_accuracy did not improve from 0.99419
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9912 - loss: 0.0298 - val_accuracy: 0.9940 - val_loss: 0.0254 - learning_rate: 5.0000e-04
# Epoch 36/100
# 381/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.0275
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 36: val_accuracy did not improve from 0.99419
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9922 - loss: 0.0276 - val_accuracy: 0.9936 - val_loss: 0.0267 - learning_rate: 5.0000e-04
# Epoch 37/100
# 391/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0274
# Epoch 37: val_accuracy improved from 0.99419 to 0.99497, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0274 - val_accuracy: 0.9950 - val_loss: 0.0236 - learning_rate: 2.5000e-04
# Epoch 38/100
# 387/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0218
# Epoch 38: val_accuracy did not improve from 0.99497
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - loss: 0.0218 - val_accuracy: 0.9945 - val_loss: 0.0242 - learning_rate: 2.5000e-04
# Epoch 39/100
# 380/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0237
# Epoch 39: val_accuracy did not improve from 0.99497
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9930 - loss: 0.0236 - val_accuracy: 0.9932 - val_loss: 0.0257 - learning_rate: 2.5000e-04
# Epoch 40/100
# 378/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0208
# Epoch 40: val_accuracy did not improve from 0.99497
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9937 - loss: 0.0209 - val_accuracy: 0.9943 - val_loss: 0.0233 - learning_rate: 2.5000e-04
# Epoch 41/100
# 379/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0217
# Epoch 41: val_accuracy did not improve from 0.99497
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - loss: 0.0218 - val_accuracy: 0.9947 - val_loss: 0.0223 - learning_rate: 2.5000e-04
# Epoch 42/100
# 390/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0235
# Epoch 42: val_accuracy improved from 0.99497 to 0.99505, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9930 - loss: 0.0234 - val_accuracy: 0.9951 - val_loss: 0.0225 - learning_rate: 2.5000e-04
# Epoch 43/100
# 390/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0198
# Epoch 43: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9933 - loss: 0.0198 - val_accuracy: 0.9944 - val_loss: 0.0230 - learning_rate: 2.5000e-04
# Epoch 44/100
# 381/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0215
# Epoch 44: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - loss: 0.0215 - val_accuracy: 0.9946 - val_loss: 0.0234 - learning_rate: 2.5000e-04
# Epoch 45/100
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0216
# Epoch 45: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - loss: 0.0216 - val_accuracy: 0.9945 - val_loss: 0.0229 - learning_rate: 2.5000e-04
# Epoch 46/100
# 395/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0192
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 46: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9938 - loss: 0.0193 - val_accuracy: 0.9941 - val_loss: 0.0233 - learning_rate: 2.5000e-04
# Epoch 47/100
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0201
# Epoch 47: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9939 - loss: 0.0201 - val_accuracy: 0.9947 - val_loss: 0.0222 - learning_rate: 1.2500e-04
# Epoch 48/100
# 387/398 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9940 - loss: 0.0192
# Epoch 48: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9940 - loss: 0.0192 - val_accuracy: 0.9949 - val_loss: 0.0226 - learning_rate: 1.2500e-04
# Epoch 49/100
# 396/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0190
# Epoch 49: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9937 - loss: 0.0190 - val_accuracy: 0.9947 - val_loss: 0.0226 - learning_rate: 1.2500e-04
# Epoch 50/100
# 382/398 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9941 - loss: 0.0182
# Epoch 50: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9941 - loss: 0.0182 - val_accuracy: 0.9949 - val_loss: 0.0229 - learning_rate: 1.2500e-04
# Epoch 51/100
# 387/398 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9946 - loss: 0.0174
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 51: val_accuracy did not improve from 0.99505
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9946 - loss: 0.0174 - val_accuracy: 0.9950 - val_loss: 0.0223 - learning_rate: 1.2500e-04
# Epoch 52/100
# 392/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0181
# Epoch 52: val_accuracy improved from 0.99505 to 0.99529, saving model to best_asl_model.h5
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9944 - loss: 0.0182 - val_accuracy: 0.9953 - val_loss: 0.0223 - learning_rate: 6.2500e-05
# Epoch 53/100
# 387/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0184
# Epoch 53: val_accuracy did not improve from 0.99529
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9944 - loss: 0.0184 - val_accuracy: 0.9952 - val_loss: 0.0224 - learning_rate: 6.2500e-05
# Epoch 54/100
# 382/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.0188
# Epoch 54: val_accuracy did not improve from 0.99529
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9942 - loss: 0.0188 - val_accuracy: 0.9950 - val_loss: 0.0229 - learning_rate: 6.2500e-05
# Epoch 55/100
# 393/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9950 - loss: 0.0161
# Epoch 55: val_accuracy did not improve from 0.99529
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9950 - loss: 0.0162 - val_accuracy: 0.9950 - val_loss: 0.0224 - learning_rate: 6.2500e-05
# Epoch 56/100
# 381/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0171
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 56: val_accuracy did not improve from 0.99529
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9944 - loss: 0.0171 - val_accuracy: 0.9950 - val_loss: 0.0227 - learning_rate: 6.2500e-05
# Epoch 57/100
# 382/398 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0179
# Epoch 57: val_accuracy did not improve from 0.99529
# 398/398 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9945 - loss: 0.0179 - val_accuracy: 0.9950 - val_loss: 0.0226 - learning_rate: 3.1250e-05
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 47.
#
# ✅ Training complete!
#
# 📊 Evaluating...
# ============================================================
# 📈 Results:
#   Train Accuracy: 99.78%
#   Test Accuracy: 99.53%
#   Train Loss: 0.0064
#   Test Loss: 0.0223
#
# 📋 Classification Report:
# ============================================================
#               precision    recall  f1-score   support
#
#            A      0.995     0.998     0.997       437
#            B      1.000     1.000     1.000       441
#            C      0.995     0.997     0.996       398
#            D      0.998     0.998     0.998       493
#            E      0.996     0.994     0.995       462
#            F      0.995     0.998     0.997       575
#            G      0.998     0.996     0.997       488
#            H      0.998     1.000     0.999       479
#            I      0.990     0.990     0.990       477
#            J      0.994     0.996     0.995       516
#            K      0.998     1.000     0.999       540
#            L      1.000     0.996     0.998       505
#            M      0.966     0.987     0.976       313
#            N      0.984     0.961     0.972       255
#            O      0.996     0.991     0.993       453
#            P      0.998     0.998     0.998       408
#            Q      0.998     0.998     0.998       419
#            R      1.000     0.990     0.995       508
#            S      0.992     1.000     0.996       510
#            T      1.000     0.989     0.995       470
#            U      0.998     0.996     0.997       503
#            V      0.996     0.996     0.996       510
#            W      0.996     0.996     0.996       491
#            X      0.993     0.993     0.993       432
#            Y      1.000     1.000     1.000       517
#            Z      0.996     0.996     0.996       470
#          del      0.991     1.000     0.996       340
#      nothing      1.000     1.000     1.000         1
#        space      0.991     0.997     0.994       325
#
#     accuracy                          0.995     12736
#    macro avg      0.995     0.995     0.995     12736
# weighted avg      0.995     0.995     0.995     12736
#
#
# 📊 Confusion Matrix...
# ============================================================
# 📈 Training curves...
# ============================================================
# 💾 Saving files...
# ============================================================
# ✅ asl_model.h5
# ✅ label_encoder.pkl
# ✅ scaler.pkl
#
# ============================================================
# 🎉 PHASE 2 COMPLETE!
# ============================================================
#
# 📥 Download these 3 files:
#   • asl_model.h5
#   • label_encoder.pkl
#   • scaler.pkl
#
# 🚀 Next: Build Streamlit app!
